# %%
from agent.kinoteatr_ru_agent import KinoteatrRuAgent

# pip install -r requirements.txt
app = KinoteatrRuAgent().compiled_graph

# %%
display(app)

# %%
answer = await app.ainvoke({"question": "Я живу в Санкт-Петербурге на станции метро Маяковская и хочу пойти в кино где-то после 18:30. Учитывай погоду на улице."})
# Out:
# 1 ч. 21 мин.  list index out of range

# %%
print(answer["answer"])
# Out:
# **🎬 Вечер в кино: Санкт-Петербург, 2 декабря 2025**
#
# 📍 **Кинотеатр:** Galeria (Формула Кино Галерея)
# адрес: Санкт-Петербург, Лиговский проспект, 30а, ТРЦ «Галерея»
# 🚇 Ближайшая станция метро: Площадь Восстания
#
# ---
#
# **🍿 Рекомендации на вечер:**
#
# 1. **"Человек-бензопила. Фильм: История Резе"**
#    - **Время сеанса:** 19:00
#    - **Длительность:** 99 мин
#    - **Жанр:** Аниме, фэнтези, ужасы
#    - **Цена билетов:** от 500 до 700 ₽ (в зависимости от зала и времени покупки)
#    - **Почему смотреть:** Захватывающий аниме-фильм с необычным сюжетом и яркой визуальной атмосферой — идеальный вариант для уютного вечернего киносеанса.
#
# 2. **"Сущность"**
#    - **Время сеанса:** 22:45
#    - **Длительность:** 98 мин
#    - **Жанр:** Психологический хоррор, триллер
#    - **Цена билетов:** от 550 до 750 ₽
#    - **Почему смотреть:** Атмосферный и напряженный триллер, подходящий для позднего вечера. Отлично подойдет, если вы любите глубокие и интригующие истории.
#
# 3. **"По-братски"**
#    - **Время сеанса:** 21:50
#    - **Длительность:** 96 мин
#    - **Жанр:** Русская комедия
#    - **Цена билетов:** от 450 до 650 ₽
#    - **Почему смотреть:** Легкий и смешной фильм для компании — отличный выбор, если вы хотите провести время в добром настроении.
#
# ---
#
# **🌤 Погода:**
# 2 декабря — облачно, без осадков. Температура вечером около 3.5°C, ночью до 1.8°C. Ветер и высокая влажность придают прохладу, поэтому лучше взять с собой теплую куртку.
#
# ---
#
# **🎟 Совет:**
# Забронируйте билеты заранее на сайте или в мобильном приложении кинотеатра, чтобы избежать очередей. Учитывайте погодные условия — приезд лучше запланировать с небольшим запасом времени.
#
# **Приятного просмотра и уютного вечера в кино! 🎥✨**
