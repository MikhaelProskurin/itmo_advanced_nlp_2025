# %%
from agent.kinoteatr_ru_agent import KinoteatrRuAgent


# just make .env file with those variables and place it in the project root.
# - LLM_API_KEY (typical api-key for llm access)
# - BASE_URL (endpoint of llm-inference-server)
# - WEATHER_API_KEY (api.openweathermap.org)

# then, install project dependencies
# pip install -r requirements.txt

app = KinoteatrRuAgent().compiled_graph

# %%
display(app)

# %%
answer = await app.ainvoke({"question": "Я живу в Санкт-Петербурге на станции метро Достоевская и хочу пойти в кино где-то после 19:30. Учитывай погоду на улице."})

# %%
print(answer["answer"])
# Out:
# 🍿 **План идеального вечернего киносеанса в Санкт-Петербурге** 🎬
#
# 1. **Выберите кинотеатр: "Формула Кино Меркурий"**
#    Расположен по адресу: ул. Савушкина, д. 141, ТРЦ "Меркурий".
#    Ближайшая станция метро: **Беговая** 🚇.
#    Современный и уютный кинотеатр с комфортными залами и отличным звуком.
#
# 2. **Выберите фильм и время сеанса (все начинаются поздно — 23:45–23:55):**
#    - 🎩 **"Иллюзия обмана 3"** — триллер с магией и головокружительными трюками.
#    - 🐺 **"Волчок"** — приключенческая комедия с динамичным сюжетом.
#    - 🕯️ **"Крипер"** — напряженный хоррор для любителей атмосферного ужаса.
#    Билеты можно приобрести онлайн или на месте — обычно цены варьируются от **250 до 350 рублей**, в зависимости от зала и времени сеанса.
#
# 3. **Учитывайте погоду:**
#    Ночью возможен легкий дождь 🌧️, температура около 4°C и высокая влажность.
#    Рекомендуем взять с собой зонт и теплую куртку.
#
# ...
