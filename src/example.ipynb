# %%
from agent.kinoteatr_ru_agent import KinoteatrRuAgent

# pip install -r requirements.txt
app = KinoteatrRuAgent().compiled_graph

# %%
display(app)

# %%
answer = await app.ainvoke({"question": "Я живу в Санкт-Петербурге на станции метро Маяковская и хочу пойти в кино где-то после 18:30. Учитывай погоду на улице."})

# %%
print(answer["answer"])
# Out:
# 🎬 **План идеального вечернего киносеанса в Санкт-Петербурге** 🎬
#
# ---
#
# **1. Кинотеатр: «Формула Кино Меркурий» (Merkury)**
# 📍 Адрес: Санкт-Петербург, улица Савушкина, 141, ТРЦ "Меркурий"
# 🚇 Рядом с метро: **Беговая** (удобная доступность)
# 🎫 Кинотеатр предлагает современные залы, удобные места и качественное звуковое сопровождение.
#
# ---
#
# **2. Рекомендуемые сеансы после 18:30:**
#
# - **"Иллюзия обмана 3"**
#   ⏰ 21:30 | 🕒 112 мин
#   💵 Стоимость: от 300 до 500 ₽ (в зависимости от зала и дня)
#   🧠 Триллер, криминал — для любителей напряжённого сюжета и визуальных трюков.
#
# - **"Умри, моя любовь"**
#   ⏰ 23:45 | 🕒 118 мин
#   💵 Стоимость: от 350 до 550 ₽
#   🎭 Психологический триллер с Дженнифер Лоуренс и Робертом Паттинсоном — для ценителей атмосферного кино.
#
# - **"По-братски"**
#   ⏰ 21:15 | 🕒 96 мин
#   💵 Стоимость: от 300 до 450 ₽
#   😂 Семейная комедия с добрым юмором — отличный выбор, если хочется расслабиться.
#
# ---
#
# **3. Погода и комфорт:**
# ...
